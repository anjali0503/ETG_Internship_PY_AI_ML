# %%
import json
print("NOTE: IF YOU ARE FIND RUN TIME KEY-ERROR THEN TOY ARE RE-RUN CODE AND ENTER RIGHT ID WHICH IS EXIT IN LIST")
print("if you are admin then write 1 and if you user then write 2")

girl=open("girl_store.json",'r')
girl_store = json.load(girl)
girl.close()

boy=open("boy_store.json",'r')
boy_store = json.load(boy)
boy.close()

sale=open("sales.json",'r')
sales = json.load(sale)
sale.close()

gs=json.dumps(girl_store)
girl=open("girl_store.json",'w')
girl.write(gs)
girl.close()


bs=json.dumps(boy_store)
boy=open("boy_store.json",'w')
boy.write(bs)
boy.close()

s=json.dumps(sales)
sale=open("sales.json",'w')
sale.write(s)
sale.close()


no=int(input("enter no 1 or 2 : "))

if no==1 :
    print("here admin only")
    pwd="admin123"
    password=input("enter password")
    if password==pwd:
        print("you are change data or add data")
        cd="change data"
        ad="add data"
        note=input("change data or add data")
        if cd==note:
            data=input("which data you are change : ")
        
            if data=="perfume_ID":
                print("you are now able to change id")
                g_b = str(input("which id change girl_store or boy_store"))
            
            
                if g_b == "girl_store":
                    print("you are enter in girl store : ")
                    data = str(input("enter perfume_ID : "))
                    print(girl_store[data]["perfume_name"])
                    print("you are now change perfume_ID")
                    new_ID = int(input("enter new ID"))
                    girl_store[data]["perfume_ID"] = new_ID
                    gs=json.dumps(girl_store)
                    girl=open("girl_store.json",'w')
                    girl.write(gs)
                    girl.close()
                    
                    girl=open("girl_store.json",'r')
                    g=girl.read()
                    girl.close()
                    print("ID is sucessfull change")
                else :
                    print("you are enter in boy store")
                    data = str(input("enter perfume_ID"))
                    print(boy_store[data]["perfume_name"])
                    print("you are now change perfume_ID")
                    new_ID = int(input("enter new ID"))
                    boy_store[data]["perfume_ID"] = new_ID
                    bs=json.dumps(boy_store)
                    boy=open("boy_store.json",'w')
                    boy.write(bs)
                    boy.close()

                    boy=open("boy_store.json",'r')
                    b=boy.read()
                    boy.close()
                    print("ID is sucessfull change")


            elif data=="perfume_name":
                print("you are now able to change name")
                g_b = str(input("which id change girl_store or boy_store"))
                
                if g_b == "girl_store":
                    print("you are enter in girl store : ")
                    data = str(input("enter perfume_ID which is change name"))
                    print(girl_store[data]["perfume_name"])
                    print("you are now change perfume_name")
                    new_name = input("enter new name")
                    girl_store[data]["perfume_name"] = new_name
                    gs=json.dumps(girl_store)
                    girl=open("girl_store.json",'w')
                    girl.write(gs)
                    girl.close()

                    girl=open("girl_store.json",'r')
                    g=girl.read()
                    girl.close()
                    print("name is sucessfull change")

                    

                else :
                    print("you are enter in boy store")
                    data = str(input("enter perfume_ID which is change name"))
                    print(boy_store[data]["perfume_name"])
                    print("you are now change perfume_name")
                    new_name = str(input("enter new name"))
                    boy_store[data]["perfume_name"] = new_name
                    bs=json.dumps(boy_store)
                    boy=open("boy_store.json",'w')
                    boy.write(bs)
                    boy.close()

                    boy=open("boy_store.json",'r')
                    b=boy.read()
                    boy.close()
                    print("name is sucessfull change")


                    

            elif data=="perfume_price":
                print("you are now able to change price")
                g_b = str(input("which id change girl_store or boy_store"))


                if g_b == "girl_store":
                    print("you are enter in girl store : ")
                    data = str(input("enter perfume_ID which is change price"))
                    print(girl_store[data]["perfume_name"])
                    print("you are now change perfume_price")
                    new_price = int(input("enter new price"))
                    girl_store[data]["Price"] = new_price
                    gs=json.dumps(girl_store)
                    girl=open("girl_store.json",'w')
                    girl.write(gs)
                    girl.close()

                    girl=open("girl_store.json",'r')
                    g=girl.read()
                    girl.close()
                    print("price is sucessfull change")

                    
                else :
                    print("you are enter in boy store")
                    data = str(input("enter perfume_ID which is change price"))
                    print(boy_store[data]["perfume_name"])
                    print("you are now change perfume_price")
                    new_price = int(input("enter new price"))
                    boy_store[data]["price"] = new_price
                    bs=json.dumps(boy_store)
                    boy=open("boy_store.json",'w')
                    boy.write(bs)
                    boy.close()

                    boy=open("boy_store.json",'r')
                    b=boy.read()
                    boy.close()
                    print("price is sucessfull change")

            elif data=="rate":
                print("you are now able to change rate")
                g_b = str(input("which data change girl_store or boy_store"))


                if g_b == "girl_store":
                    print("you are enter in girl store : ")
                    data = str(input("enter perfume_ID which is change rate"))
                    print(girl_store[data]["perfume_name"])
                    print("you are now change perfume_rate")
                    new_rate = float(input("enter new rate"))
                    girl_store[data]["rate"] = new_rate
                    gs=json.dumps(girl_store)
                    girl=open("girl_store.json",'w')
                    girl.write(gs)
                    girl.close()

                    girl=open("girl_store.json",'r')
                    g=girl.read()
                    girl.close()
                    print("rate is sucessfull change")
                    
                else :
                    print("you are enter in boy store")
                    data = input("enter perfume_ID which is change price")
                    print(boy_store[data]["perfume_name"])
                    print("you are now change perfume_price")
                    new_rate = float(input("enter new rate"))
                    boy_store[data]["rate"] = new_rate
                    bs=json.dumps(boy_store)
                    boy=open("boy_store.json",'w')
                    boy.write(bs)
                    boy.close()

                    boy=open("boy_store.json",'r')
                    b=boy.read()
                    boy.close()
                    print("rate is sucessfull change")


            elif data=="discount":
                print("you are now able to change discount")
                g_b = str(input("which id change girl_store or boy_store"))


                if g_b == "girl_store":
                    print("you are enter in girl store : ")
                    data = input("enter perfume_ID which is change discount")
                    print(girl_store[data]["perfume_name"])
                    print("you are now change perfume_discount : ")
                    new_discount = int(input("enter new discount"))
                    girl_store[data]["discount"] = new_discount
                    gs=json.dumps(girl_store)
                    girl=open("girl_store.json",'w')
                    girl.write(gs)
                    girl.close()

                    girl=open("girl_store.json",'r')
                    g=girl.read()
                    girl.close()
                    print("discount is sucessfull change")


                else :
                    print("you are enter in boy store")
                    data = input("enter perfume_ID which is change discount : ")
                    print(boy_store[data]["perfume_name"])
                    print("you are now change perfume_discount")
                    new_discount = int(input("enter new discount"))
                    boy_store[data]["discount"] = new_discount
                    bs=json.dumps(boy_store)
                    boy=open("boy_store.json",'w')
                    boy.write(bs)
                    boy.close()

                    boy=open("boy_store.json",'r')
                    b=boy.read()
                    boy.close()
                    print("discount is sucessfull change")
                
            else:
                print("enter correct tuple name")
        
        else:
            print("you are now add data")
            data=input("where is data add girl_store or boy_store")
            if data == "girl_store":
                print("add your data in girl_store")
                
                perfume_ID=int(input("enter perfume_id"))
                perfume_name=input("enter perfume_name")
                price=int(input("enter perfume_price"))
                rate=float(input("enter perfume_rate"))
                discount=int(input("enter perfume_discount"))
                
                girl_store[perfume_ID]={'perfume_ID': perfume_ID,'perfume_name': perfume_name, 'Price': price, 'rate': rate, 'discount': discount }
                print("data added ")
                gs=json.dumps(girl_store)
                girl=open("girl_store.json",'w')
                girl.write(gs)
                girl.close()
                    
                girl=open("girl_store.json",'r')
                g=girl.read()
                girl.close()
            elif data == "boy_store":
                print("addyour data in boy_store")
                
                perfume_ID=int(input("enter perfume_id"))
                perfume_name=input("enter perfume_name")
                price=int(input("enter perfume_price"))
                rate=float(input("enter perfume_rate"))
                discount=int(input("enter perfume_discount"))
                
                boy_store[perfume_ID]={'perfume_ID': perfume_ID,'perfume_name': perfume_name, 'Price': price, 'rate': rate, 'discount': discount }
                print("data added ")
                bs=json.dumps(boy_store)
                boy=open("boy_store.json",'w')
                boy.write(bs)
                boy.close()

                boy=open("boy_store.json",'r')
                b=boy.read()
                boy.close()
            else:
                print("you are not able to add data,thank you")
        
    else:
        print("enter correct password")
else:
    print("here user use")
    print("which perfume you want to buy")
    pn = str(input("girl_store or boy_store"))
    if pn=="girl_store":
        print("now you are buy perfume")
        data=str(input("enter perfume_ID,which is you buy perfume"))
        quantity=int(input("how many perfume you buy for this ID"))
        print("perfume_ID :" ,girl_store[data]["perfume_ID"])
        print("perfume_name : " ,girl_store[data]["perfume_name"])
        print("price : ",girl_store[data]["Price"])
        print("rate : ",girl_store[data]["rate"])
        print("discount : ",girl_store[data]["discount"])
        print("******************************************")
        print("product quantity : " ,quantity)
        total_bill=float(quantity*girl_store[data]["Price"])
        print("total bill without discount :" ,total_bill)
        print("******************************************")
        discount_percentage = int(girl_store[data]["discount"])
        print("discount Percentage : ",discount_percentage)
        discount_price = float((total_bill * discount_percentage)/100)
        print("discount Price : ",discount_price)
        print("******************************************")
        final_amount = float(total_bill - discount_price)
        print("Final Amount with discount :" ,final_amount)
        
        sales[data]={'perfume_ID': data,'discount_price': discount_price ,'billing amount':final_amount}
        
        s=json.dumps(sales)
        sale=open("sales.json",'w')
        sale.write(s)
        sale.close()
        
        sale=open("sales.json",'r')
        sales = json.load(sale)
        sale.close()
        
        

        
    elif pn=="boy_store":
        print("now you are buy perfum")
        data=str(input("enter perfume_ID,which is you buy perfume"))
        quantity=int(input("how many perfume you buy for this ID"))
        print("perfume_ID :" ,boy_store[data]["perfume_ID"])
        print("perfume_name : " ,boy_store[data]["perfume_name"])
        print("price : ",boy_store[data]["price"])
        print("rate : ",boy_store[data]["rate"])
        print("discount : ",boy_store[data]["discount"])
        print("******************************************")
        print("product quantity : " ,quantity)
        total_bill=float(quantity*boy_store[data]["price"])
        print("total bill without discount :" ,total_bill)
        print("******************************************")
        discount_percentage = int(boy_store[data]["discount"])
        print("discount Percentage : ",discount_percentage)
        discount_price = float((total_bill * discount_percentage)/100)
        print("discount Price : ",discount_price)
        print("******************************************")
        final_amount = float(total_bill - discount_price)
        print("Final Amount with discount :" ,final_amount)
        
        sale=open("sales.json",'r')
        sales = json.load(sale)
        sale.close()
        
        s=json.dumps(sales)
        sale=open("sales.json",'w')
        sale.write(s)
        sale.close()
        
    else:
        print("sorry not find,search agin!")
# Out:
# NOTE: IF YOU ARE FIND RUN TIME KEY-ERROR THEN YOU ARE RE-RUN CODE AND ENTER RIGHT ID WHICH IS EXIT IN LIST
# if you are admin then write 1 and if you user then write 2
# enter no 1 or 2 : 1
# here admin only
# enter passwordadmin123
# you are change data or add data
# change data or add dataadd data
# you are now add data
# where is data add girl_store or boy_storegirl_store
# add your data in girl_store
# enter perfume_id87846
# enter perfume_namedgysdsd
# enter perfume_price5656
# enter perfume_rate54
# enter perfume_discount56
# data added

# %%
girl_store.keys()
# Out:
# dict_keys(['123456', '123457', '123458', '123459', '123460', '123461', '123462', '123463', '123464', '123465', '123466', '123467', '123468', '123469', '123470', '848646', '846848'])

# %%
boy_store.keys()
# Out:
# dict_keys(['123471', '123472', '123473', '123474', '123475', '123476', '123477', '123478', '123479', '123480', '123481', '123482', '123483', '123484', '123485'])

# %%
gs
# Out:
# '{"123456": {"perfume_ID": 987456, "perfume_name": "ytdyugfyu", "Price": 759, "rate": 5.2, "discount": "10", "price": 564}, "123457": {"perfume_ID": 123457, "perfume_name": "LOVE_posion", "Price": 759, "rate": 4.4, "discount": "30"}, "123458": {"perfume_ID": 123458, "perfume_name": "LOVE_wottagirl", "Price": 759, "rate": 4.4, "discount": "20"}, "123459": {"perfume_ID": 123459, "perfume_name": "kelvin_lekin", "Price": 759, "rate": 4.4, "discount": "20"}, "123460": {"perfume_ID": 123460, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123461": {"perfume_ID": 123461, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123462": {"perfume_ID": 123462, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123463": {"perfume_ID": 123463, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123464": {"perfume_ID": 123464, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "1234
# ...

# %%
bs
# Out:
# '{"123471": {"perfume_ID": 563241, "perfume_name": "gfyhygf", "Price": 759, "rate": 4.4, "discount": "10", "price": 50}, "123472": {"perfume_ID": 123472, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "30"}, "123473": {"perfume_ID": 123473, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123474": {"perfume_ID": 123474, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123475": {"perfume_ID": 123475, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123476": {"perfume_ID": 123476, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123477": {"perfume_ID": 123477, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123478": {"perfume_ID": 123478, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123479": {"perfume_ID": 123479, "perfume_name": "LOVE_EDT", "Price": 759, "rate": 4.4, "discount": "20"}, "123480": {"perfume_I
# ...

# %%
sales
# Out:
# {'123456': {'perfume_ID': '123456',
#   'discount_price': 169.2,
#   'billing amount': 1522.8},
#  '123457': {'perfume_ID': '123457',
#   'discount_price': 683.1,
#   'billing amount': 1593.9},
#  '123458': {'perfume_ID': '123458',
#   'discount_price': 455.4,
#   'billing amount': 1821.6}}
